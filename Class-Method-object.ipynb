# %% [markdown]
# #### 1- CLASS
# #### 2- METHOD
# #### 3- OBJECT

# %%
a = 5
print(type(a)) #inbuild class
# Out:
# <class 'int'>

# %%
l = [1,2,3]
print(type(l))
# Out:
# <class 'list'>

# %%
class computer():        
    def config():     
        print('i5', '8gb') 

com1 = computer()

# %%
class computer():        
    def config():     
        print('i5', '8gb') 
        
a = '8'
print(type(a))

com1 = computer() 
print(type(com1))
# Out:
# <class 'str'>
# <class '__main__.computer'>

# %%
print(id(a))
print(id(com1))
# Out:
# 140707038762640
# 1824858847568

# %%
class computer():        
    def config():     
        print('i5', '8gb') 
       
com1 = computer() 

computer.config()
# Out:
# i5 8gb

# %%
class computer():        
    def config():     
        print('i5', '8gb') 
        
com1 = computer() 
com1.config()

# %%
class computer():        
    def config(self):     
        print('i5', '8gb') 
        
com1 = computer() 

com1.config()
# Out:
# i5 8gb

# %%
class computer():        
    def config(self):     
        print('i5', '8gb') 
        
com1 = computer() 
com2 = computer()
com3 = computer()

com1.config()
com2.config()
com3.config()
# Out:
# i5 8gb
# i5 8gb
# i5 8gb

# %%
print(id(com1))
print(id(com2))
print(id(com3))
# Out:
# 1824864340112
# 1824860596336
# 1824864252320
